# %% [markdown]
# # 02 — Geographic Analytics
# Choropleth maps and hotspot analysis.

# %%
import pandas as pd
from src.utils.db import get_engine
from src.analytics.geo_analysis import aggregate_by_region, hotspot_score, add_distance_to_point
from src.analytics.heatmap import plotly_state_choropleth, folium_point_heatmap

# %%
eng = get_engine()
df = pd.read_sql("SELECT * FROM fact_housing_listing_clean", eng)
df.shape

# %%
state_agg = aggregate_by_region(df, "state_code")
state_agg.head()

# %%
plotly_state_choropleth(state_agg.rename(columns={"avg_price":"avg_sale_price"}))

# %%
hot = hotspot_score(df)
hot.head(15)

# %%
folium_point_heatmap(df)
