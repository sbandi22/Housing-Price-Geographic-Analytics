# %% [markdown]
# # 03 — Price Prediction Modeling
# OLS regression + Gradient Boosting with feature importance.

# %%
import pandas as pd
from src.utils.db import get_engine
from src.models.regression import fit_ols, summary_table
from src.models.price_predictor import train

# %%
eng = get_engine()
df = pd.read_sql("SELECT * FROM fact_housing_listing_clean", eng)
df.shape

# %% [markdown]
# ## Baseline OLS

# %%
ols = fit_ols(df)
summary_table(ols).head(15)

# %% [markdown]
# ## Gradient Boosting

# %%
metrics = train(df)
metrics
