# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# End-to-end EDA over housing, demographic, and economic data.
# Run cells top-to-bottom after the ETL pipeline has loaded the warehouse.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.utils.db import get_engine
from src.analytics.stats import describe, groupwise_summary
from src.analytics.correlation import pearson_matrix, target_correlations, plot_heatmap

sns.set_theme(style='whitegrid')

# %% [markdown]
# ## Load cleaned housing facts

# %%
eng = get_engine()
df = pd.read_sql('SELECT * FROM fact_housing_listing_clean', eng)
df.shape

# %% [markdown]
# ## Univariate summary for sale price

# %%
describe(df['sale_price'])

# %% [markdown]
# ## Distribution

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
sns.histplot(df['sale_price'], bins=40, kde=True, ax=ax[0])
ax[0].set_title('Sale price distribution')
sns.histplot(np.log1p(df['sale_price']), bins=40, kde=True, ax=ax[1])
ax[1].set_title('Log sale price')
plt.tight_layout()

# %% [markdown]
# ## Top correlations with price

# %%
tc = target_correlations(df, 'sale_price')
tc.head(15)

# %%
plot_heatmap(pearson_matrix(df), title='Pearson correlation — housing drivers')
